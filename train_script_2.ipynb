# %% [markdown]
# ### 🛠️ Teknologi Utama:
# | Komponen | Teknologi | Fungsi |
# |---|---|---|
# | **Embeddings** | Sentence-BERT (E5-Large) | Mengubah teks deskripsi menjadi vektor numerik 1024-dimensi |
# | **Classifier** | Logistic Regression | Memprediksi kategori transaksi menggunakan pendekatan probabilitas |
# | **Optimization** | GridSearchCV | Menemukan parameter regularisasi (C) terbaik secara otomatis |
# | **Prefixing** | `query:` | Meningkatkan akurasi retrieval pada model E5 |

# %%
# !pip install sentence-transformers scikit-learn pandas numpy joblib -q

# %% [markdown]
# ## ⚙️ Konfigurasi

# %%
import os

DATASET_PATH = "https://drive.google.com/uc?export=download&id=13fLircDw0aeY2rPGN4UnnYIWLmN429lQ"

MODEL_OUTPUT_PATH = "classifier_model.joblib"

# Model embedding
MODEL_NAME = "intfloat/multilingual-e5-large"

CLASSIFIER_TYPE = "logreg"

# GridSearch — True untuk mencari parameter C dan Gamma terbaik secara otomatis
USE_GRID_SEARCH = True

print("✓ Konfigurasi siap")
print(f"  Model     : {MODEL_NAME}")
if CLASSIFIER_TYPE == "logreg":
    print(f"  Classifier: {CLASSIFIER_TYPE.upper()} (Logistic Regression)")
elif CLASSIFIER_TYPE == "svc":
    print(f"  Classifier: {CLASSIFIER_TYPE.upper()} (SVM)")
else:
    print(f"  Classifier: {CLASSIFIER_TYPE.upper()}")
print(f"  GridSearch: {USE_GRID_SEARCH}")
# Out:
# ✓ Konfigurasi siap
#   Model     : intfloat/multilingual-e5-large
#   Classifier: LOGREG (Logistic Regression)
#   GridSearch: True

# %% [markdown]
# ## 📚 Import Libraries

# %%
import pandas as pd
import numpy as np
import time
import joblib
import re
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import csv
import json
import os
import urllib.request
import random

from sentence_transformers import SentenceTransformer
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    classification_report,
    accuracy_score,
    ConfusionMatrixDisplay,
    confusion_matrix,
)

matplotlib.rcParams['figure.dpi'] = 120

print("✓ Semua library berhasil diimport")
# Out:
# ✓ Semua library berhasil diimport

# %% [markdown]
# ## 1️⃣ Load & Eksplorasi Dataset

# %%
print(f"Membaca dataset dari:\n  {DATASET_PATH}\n")

df = pd.read_csv(DATASET_PATH)

print(f"Total baris   : {len(df)}")
print(f"Kolom         : {df.columns.tolist()}")
print(f"Jumlah kategori: {df['Kategori'].nunique()}")
print(f"Duplikat      : {df.duplicated(subset=['Deskripsi']).sum()} baris")
print()
df.head()

# Distribusi data per kategori
dist = df['Kategori'].value_counts()

fig, ax = plt.subplots(figsize=(10, 8))
colors = ['#e74c3c' if v < 60 else '#2ecc71' for v in dist.values]
dist.plot(kind='barh', ax=ax, color=colors)
ax.axvline(x=60, color='orange', linestyle='--', linewidth=1.5, label='Threshold 60 sampel')
ax.set_title('Distribusi Data per Kategori', fontsize=13, fontweight='bold')
ax.set_xlabel('Jumlah sampel')
ax.legend()
plt.tight_layout()
plt.show()

print(f"\nKategori dengan sampel < 60: {(dist < 60).sum()} kategori")
print(f"Min sampel: {dist.min()} ({dist.idxmin()})")
print(f"Max sampel: {dist.max()} ({dist.idxmax()})")
# Out:
# Membaca dataset dari:
#   https://drive.google.com/uc?export=download&id=13fLircDw0aeY2rPGN4UnnYIWLmN429lQ
#
# Total baris   : 6930
# Kolom         : ['Deskripsi', 'Kategori']
# Jumlah kategori: 41
# Duplikat      : 0 baris
# Kategori dengan sampel < 60: 0 kategori
# Min sampel: 156 (Kebersihan & Toiletries)
# Max sampel: 192 (Perawatan Diri)

# %%
unique_categories = df['Kategori'].unique().tolist()
print(f"Daftar kategori unik:\n{unique_categories}")
print(f"Total kategori unik: {len(unique_categories)}")
# Out:
# Daftar kategori unik:
# ['Perbaikan & Maintenance', 'Biaya Darurat', 'Tagihan', 'Asuransi', 'Perawatan Diri', 'Kebersihan & Toiletries', 'Jasa Profesional', 'Transportasi', 'Pendidikan', 'Biaya Admin & Bank', 'Parkir & Tol', 'Donasi/Zakat', 'Langganan Digital', 'Keluarga', 'Cicilan & Utang', 'Pajak', 'Belanja Harian', 'Perlengkapan Rumah', 'Gadget & Elektronik', 'Pakaian', 'Tempat Tinggal', 'Pulsa & Data', 'Makanan & Minuman', 'Hewan Peliharaan', 'Olahraga & Fitness', 'Transfer & Topup', 'Kesehatan', 'Hiburan', 'Gaming', 'Hadiah', 'Hobi', 'Tabungan & Investasi', 'Liburan', 'Administrasi & Dokumen', 'Laundry', 'Kendaraan', 'Pernikahan & Event', 'Sosial & Komunitas', 'Rokok & Vape', 'Buku & Media', 'Anak & Bayi']
# Total kategori unik: 41

# %% [markdown]
# ## 2️⃣ Preprocessing

# %%
def clean_text(text: str) -> str:
    """
    Lowercase, buang tanda baca, normalkan spasi.
    Angka pendek (misal '5kg', '50rb') sengaja dibiarkan karena masih relevan untuk klasifikasi.
    Yang dihapus hanya angka 6 digit ke atas seperti nomor rekening atau kode transaksi.
    """
    text = str(text).lower().strip()
    text = re.sub(r'\b\d{6,}\b', '', text)   # no. rekening, kode OTP, dsb
    text = re.sub(r'[^\w\s]', ' ', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text


# Hapus missing values
df = df.dropna(subset=['Deskripsi', 'Kategori'])

# Hapus duplikat
n_before = len(df)
df = df.drop_duplicates(subset=['Deskripsi']).reset_index(drop=True)
n_removed = n_before - len(df)
print(f"✓ Duplikat dihapus: {n_removed} baris")
print(f"✓ Dataset bersih  : {len(df)} baris")

# Cleaning teks
df['teks_bersih'] = df['Deskripsi'].apply(clean_text)
print(f"\n✓ Cleaning selesai. Contoh:")
for _, row in df.sample(3, random_state=1).iterrows():
    print(f"  Asli   : {row['Deskripsi']}")
    print(f"  Bersih : {row['teks_bersih']}")
    print()
# Out:
# ✓ Duplikat dihapus: 0 baris
# ✓ Dataset bersih  : 6930 baris
#
# ✓ Cleaning selesai. Contoh:
#   Asli   : Beli baju kerja
#   Bersih : beli baju kerja
#
#   Asli   : Beli tiket pesawat Batik Air
#   Bersih : beli tiket pesawat batik air
#
#   Asli   : Bayar parkir di kantor
#   Bersih : bayar parkir di kantor

# %% [markdown]
# ## 3️⃣ Embedding
#
# Model E5 butuh prefix `"query: "` saat encoding — tanpa ini kualitas embedding turun karena model
# tidak tahu konteks penggunaan. Lihat dokumentasi `intfloat/multilingual-e5`.

# %%
def encode_texts(model: SentenceTransformer, texts: list, prefix: str = "query") -> np.ndarray:
    """
    Encode teks ke vektor embedding pakai E5.
    Prefix 'query:' untuk teks yang mau diklasifikasi, 'passage:' untuk dokumen/corpus.
    """
    texts_with_prefix = [f"{prefix}: {t}" for t in texts]
    embeddings = model.encode(
        texts_with_prefix,
        batch_size=32,
        show_progress_bar=True,
        normalize_embeddings=True,  # normalisasi langsung di encode
    )
    return embeddings


print(f"Memuat model: {MODEL_NAME}")
print("(Unduhan pertama ~beberapa menit)...")

sbert_model = SentenceTransformer(MODEL_NAME)

print(f"\n✓ Model siap!")
print(f"  Dimensi embedding: {sbert_model.get_sentence_embedding_dimension()}")

# Cache embedding ke disk — hindari encode ulang tiap re-run notebook.
# Cache otomatis invalid kalau jumlah baris dataset berubah.
EMBEDDING_CACHE = "embeddings_cache.npy"

if os.path.exists(EMBEDDING_CACHE):
    cached = np.load(EMBEDDING_CACHE)
    if len(cached) == len(df):
        print(f"✓ Pakai embedding dari cache: {EMBEDDING_CACHE}")
        embeddings = cached
    else:
        print("Cache tidak cocok dengan dataset saat ini, encode ulang...")
        embeddings = None
else:
    embeddings = None

if embeddings is None:
    print("Encoding semua teks ke vektor embedding...")
    print(f"prefix: 'query: '\n")

    t0 = time.time()
    embeddings = encode_texts(sbert_model, df['teks_bersih'].tolist(), prefix="query")
    elapsed = time.time() - t0

    print(f"\n✓ Embedding selesai dalam {elapsed:.1f}s")
    np.save(EMBEDDING_CACHE, embeddings)
    print(f"✓ Embedding disimpan ke cache: {EMBEDDING_CACHE}")

print(f"  Shape : {embeddings.shape}")
print(f"  Dtype : {embeddings.dtype}")
print(f"  Norm sample[0]: {np.linalg.norm(embeddings[0]):.4f} (harus ~1.0)")
# Out:
# Memuat model: intfloat/multilingual-e5-large
# (Unduhan pertama ~beberapa menit)...
# modules.json:   0%|          | 0.00/387 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# README.md:   0%|          | 0.00/160k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/57.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/690 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.24G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/418 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/280 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/201 [00:00<?, ?B/s]
# ✓ Model siap!
#   Dimensi embedding: 1024
# Encoding semua teks ke vektor embedding...
# prefix: 'query: '
# /tmp/ipykernel_421/4041048307.py:22: FutureWarning: The `get_sentence_embedding_dimension` method has been renamed to `get_embedding_dimension`.
#   print(f"  Dimensi embedding: {sbert_model.get_sentence_embedding_dimension()}")
# Batches:   0%|          | 0/217 [00:00<?, ?it/s]
# ✓ Embedding selesai dalam 19.0s
# ✓ Embedding disimpan ke cache: embeddings_cache.npy
#   Shape : (6930, 1024)
#   Dtype : float32
#   Norm sample[0]: 1.0000 (harus ~1.0)

# %% [markdown]
# ## 4️⃣ Train-Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    embeddings,
    df['Kategori'].tolist(),
    test_size=0.2,
    random_state=42,
    stratify=df['Kategori'],
)

print(f"✓ Data train : {len(X_train)} sampel")
print(f"✓ Data test  : {len(X_test)} sampel")
print(f"✓ Rasio      : {len(X_train)/len(embeddings)*100:.0f}% / {len(X_test)/len(embeddings)*100:.0f}%")
# Out:
# ✓ Data train : 5544 sampel
# ✓ Data test  : 1386 sampel
# ✓ Rasio      : 80% / 20%

# %% [markdown]
# ## 5️⃣ Training
#
# Logistic Regression dipilih sebagai model klasifikasi linear yang efisien dan tangguh. GridSearchCV digunakan untuk mencari parameter `C` (kekuatan regularisasi) dan `solver` terbaik melalui 3-fold cross validation guna memastikan model tidak overfitting dan memiliki performa generalisasi yang baik.

# %%
def build_classifier(classifier_type: str, use_grid_search: bool):
    if classifier_type == "svc":
        base_clf = SVC(
            kernel="rbf",
            class_weight="balanced",
            probability=True,
            random_state=42,
        )
        if use_grid_search:
            param_grid = {
                "C"    : [5, 10, 20],
                "gamma": ["scale"],
            }
            return GridSearchCV(
                base_clf, param_grid,
                cv=StratifiedKFold(n_splits=3, shuffle=True, random_state=42),
                scoring="f1_macro",
                n_jobs=-1,
                verbose=1,
            )
        else:
            return SVC(kernel="rbf", C=10, gamma="scale",
                       class_weight="balanced", probability=True, random_state=42)

    elif classifier_type == "logreg":
        base_clf = LogisticRegression(max_iter=2000, random_state=42, class_weight="balanced")
        if use_grid_search:
            param_grid = {
                "C": [0.1, 1, 10],
                "solver": ['liblinear', 'lbfgs'] # Example solvers
            }
            return GridSearchCV(
                base_clf, param_grid,
                cv=StratifiedKFold(n_splits=3, shuffle=True, random_state=42),
                scoring="f1_macro",
                n_jobs=-1,
                verbose=1,
            )
        else:
            return base_clf
    else:
        raise ValueError(f"Unknown classifier type: {classifier_type}")


clf = build_classifier(CLASSIFIER_TYPE, USE_GRID_SEARCH)

print(f"Melatih {CLASSIFIER_TYPE.upper()} classifier...")
if USE_GRID_SEARCH:
    print("GridSearchCV aktif — ini butuh beberapa menit, harap tunggu...\n")

# verbose=1 di GridSearchCV sudah cukup buat liat progres per-fold
t0 = time.time()
clf.fit(X_train, y_train)
elapsed = time.time() - t0

print(f"\n✓ Training selesai dalam {elapsed:.1f}s")

if USE_GRID_SEARCH and hasattr(clf, 'best_params_'):
    print(f"\n  Parameter terbaik  : {clf.best_params_}")
    print(f"  CV F1-macro terbaik: {clf.best_score_:.4f} ({clf.best_score_*100:.2f}%)")
# Out:
# Melatih LOGREG classifier...
# GridSearchCV aktif — ini butuh beberapa menit, harap tunggu...
#
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
#
# ✓ Training selesai dalam 139.4s
#
#   Parameter terbaik  : {'C': 10, 'solver': 'lbfgs'}
#   CV F1-macro terbaik: 0.8572 (85.72%)

# %% [markdown]
# ## 6️⃣ Evaluasi Model

# %%
y_pred = clf.predict(X_test)
acc = accuracy_score(y_test, y_pred)

print("=" * 60)
print(f"  AKURASI TOTAL: {acc * 100:.2f}%")
print("=" * 60)
print()
print(classification_report(y_test, y_pred, zero_division=0))

# Visualisasi F1-score per kategori
report = classification_report(y_test, y_pred, output_dict=True, zero_division=0)
df_report = pd.DataFrame(report).T
df_report = df_report.drop(['accuracy', 'macro avg', 'weighted avg'])
df_report = df_report.sort_values('f1-score')

fig, ax = plt.subplots(figsize=(10, 10))
colors = ['#e74c3c' if v < 0.7 else '#f39c12' if v < 0.85 else '#2ecc71'
          for v in df_report['f1-score']]
df_report['f1-score'].plot(kind='barh', ax=ax, color=colors)
ax.axvline(x=0.7,  color='red',    linestyle='--', linewidth=1, alpha=0.7, label='F1 = 0.70')
ax.axvline(x=0.85, color='orange', linestyle='--', linewidth=1, alpha=0.7, label='F1 = 0.85')
ax.set_xlim(0, 1)
ax.set_title('F1-Score per Kategori', fontsize=13, fontweight='bold')
ax.set_xlabel('F1-Score')
ax.legend(loc='lower right')

# Label nilai di kanan bar
for i, v in enumerate(df_report['f1-score']):
    ax.text(v + 0.01, i, f'{v:.2f}', va='center', fontsize=8)

plt.tight_layout()
plt.show()

# Confusion matrix untuk kategori dengan F1 < 0.75
# Identifikasi kategori lemah
weak_cats = df_report[df_report['f1-score'] < 0.75].index.tolist()
print(f"Kategori dengan F1 < 0.75 ({len(weak_cats)} kategori):")
for cat in weak_cats:
    f1 = df_report.loc[cat, 'f1-score']
    print(f"  {cat:<30} F1={f1:.2f}")

if weak_cats:
    mask_test = [y in weak_cats for y in y_test]
    y_test_weak = [y_test[i] for i in range(len(y_test)) if mask_test[i]]
    y_pred_weak = [y_pred[i] for i in range(len(y_pred)) if mask_test[i]]

    cm = confusion_matrix(y_test_weak, y_pred_weak, labels=weak_cats)

    fig, ax = plt.subplots(figsize=(max(8, len(weak_cats)*0.8), max(6, len(weak_cats)*0.7)))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Reds',
                xticklabels=weak_cats, yticklabels=weak_cats, ax=ax,
                linewidths=0.5)
    ax.set_title('Confusion Matrix — Kategori Lemah (F1 < 0.75)', fontsize=12, fontweight='bold')
    ax.set_ylabel('Aktual')
    ax.set_xlabel('Prediksi')
    plt.xticks(rotation=45, ha='right')
    plt.yticks(rotation=0)
    plt.tight_layout()
    plt.show()
# Out:
# ============================================================
#   AKURASI TOTAL: 86.94%
# ============================================================
#
#                          precision    recall  f1-score   support
#
#  Administrasi & Dokumen       0.94      0.94      0.94        33
#             Anak & Bayi       0.94      0.91      0.92        33
#                Asuransi       1.00      1.00      1.00        34
#          Belanja Harian       0.86      0.81      0.83        37
#      Biaya Admin & Bank       0.88      0.85      0.87        34
#           Biaya Darurat       0.96      0.79      0.87        34
#            Buku & Media       0.94      0.97      0.96        33
#         Cicilan & Utang       0.74      0.85      0.79        33
#            Donasi/Zakat       0.97      0.91      0.94        34
#     Gadget & Elektronik       0.94      0.91      0.92        33
#                  Gaming       0.89      0.97      0.93        33
#                  Hadiah       0.82      1.00      0.90        33
#        Hewan Peliharaan       0.91      0.91      0.91        33
#                 Hiburan       0.93      0.82      0.87        33
#                    Hobi       0.83      0.81      0.82        36
#        Jasa Profesional       0.87      0.79      0.83        33
# Kebersihan & Toiletries       0.78      0.68      0.72        31
#                Keluarga       0.92      0.72      0.81        32
#               Kendaraan       0.69      0.75      0.72        32
#               Kesehatan       0.89      0.94      0.91        33
#       Langganan Digital       0.83      1.00      0.91        34
#                 Laundry       0.94      1.00      0.97        33
#                 Liburan       0.80      0.85      0.82        33
#       Makanan & Minuman       0.78      0.74      0.76        34
#      Olahraga & Fitness       0.94      0.83      0.88        36
#                   Pajak       0.86      0.73      0.79        33
#                 Pakaian       0.80      1.00      0.89        33
#            Parkir & Tol       0.85      0.92      0.88        36
#              Pendidikan       0.85      0.91      0.88        32
#          Perawatan Diri       0.90      0.90      0.90        39
# Perbaikan & Maintenance       0.79      0.79      0.79        34
#      Perlengkapan Rumah       0.75      0.77      0.76        35
#      Pernikahan & Event       0.78      0.88      0.83        33
#            Pulsa & Data       0.95      0.95      0.95        38
#            Rokok & Vape       1.00      0.97      0.98        33
#      Sosial & Komunitas       0.86      0.91      0.88        33
#    Tabungan & Investasi       0.97      0.94      0.95        33
#                 Tagihan       0.94      0.91      0.92        33
#          Tempat Tinggal       0.79      0.70      0.74        33
#        Transfer & Topup       0.79      0.91      0.85        33
#            Transportasi       0.90      0.74      0.81        38
#
#                accuracy                           0.87      1386
#               macro avg       0.87      0.87      0.87      1386
#            weighted avg       0.87      0.87      0.87      1386
# Kategori dengan F1 < 0.75 (3 kategori):
#   Kendaraan                      F1=0.72
#   Kebersihan & Toiletries        F1=0.72
#   Tempat Tinggal                 F1=0.74

# %% [markdown]
# ### 📊 Distribusi Confidence Score
# Grafik di bawah ini menunjukkan tingkat keyakinan (confidence) model terhadap prediksi yang diberikan pada data testing.

# %%
# Mendapatkan probabilitas untuk data test
y_proba = clf.predict_proba(X_test)
# Mengambil probabilitas tertinggi (confidence score) untuk setiap baris
confidences = np.max(y_proba, axis=1) * 100

plt.figure(figsize=(10, 6))
sns.histplot(confidences, bins=20, kde=True, color='skyblue', edgecolor='black')

# Menambahkan garis rata-rata
mean_conf = np.mean(confidences)
plt.axvline(mean_conf, color='red', linestyle='--', label=f'Rata-rata: {mean_conf:.1f}%')

plt.title('Distribusi Confidence Score Hasil Klasifikasi (Data Test)', fontsize=14, fontweight='bold')
plt.xlabel('Confidence Score (%)', fontsize=12)
plt.ylabel('Jumlah Sampel', fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.legend()
plt.show()

print(f"Rata-rata tingkat keyakinan model: {mean_conf:.2f}%")
print(f"Median tingkat keyakinan model: {np.median(confidences):.2f}%")
# Out:
# Rata-rata tingkat keyakinan model: 65.04%
# Median tingkat keyakinan model: 67.85%

# %% [markdown]
# ## 7️⃣ Simpan Model

# %%
# Simpan classifier beserta metadata penting
model_bundle = {
    "classifier"      : clf,
    "model_name"      : MODEL_NAME,
    "classifier_type" : CLASSIFIER_TYPE,
    "accuracy"        : acc,
    "prefix"          : "query",  # PENTING: simpan prefix untuk inferensi
    "kategori_list"   : sorted(df['Kategori'].unique().tolist()),
}

joblib.dump(model_bundle, MODEL_OUTPUT_PATH)
print(f"✓ Model disimpan ke: {MODEL_OUTPUT_PATH}")
print(f"  Akurasi  : {acc * 100:.2f}%")
print(f"  Kategori : {len(model_bundle['kategori_list'])} kategori")
# Out:
# ✓ Model disimpan ke: classifier_model.joblib
#   Akurasi  : 86.94%
#   Kategori : 41 kategori

# %% [markdown]
# ### 📥 Download Model ke Lokal
# Jika Anda mendapatkan error 'Failed to fetch', jalankan cell di bawah ini untuk mendownload file model ke komputer Anda.

# %%
from google.colab import files
import os

if os.path.exists(MODEL_OUTPUT_PATH):
    files.download(MODEL_OUTPUT_PATH)
else:
    print(f"File {MODEL_OUTPUT_PATH} tidak ditemukan. Pastikan Anda sudah menjalankan proses training.")

# %% [markdown]
# ## 8️⃣ Inferensi — Cara Pakai Model
#
# Gunakan fungsi di bawah ini di FastAPI atau script lain. **Pastikan selalu menggunakan prefix `query: `** yang sama seperti saat training.

# %%
# load sekali di sini, bukan di dalam fungsi predict
# kalau di-load tiap request, tiap panggilan bakal baca file ~1GB dari disk
_bundle      = joblib.load(MODEL_OUTPUT_PATH)
_clf         = _bundle["classifier"]
_prefix      = _bundle.get("prefix", "query")
_sbert       = SentenceTransformer(_bundle["model_name"])

# kalau pakai GridSearchCV, .classes_ ada di best_estimator_-nya
_classes = (_clf.classes_ if hasattr(_clf, 'classes_')
            else _clf.best_estimator_.classes_)

print(f"✓ Model inference siap ({len(_classes)} kategori)")


def predict_kategori(text: str, top_k: int = 3):
    """
    Prediksi kategori untuk satu deskripsi transaksi.
    Return: (prediksi_utama, [(kategori, confidence%), ...])
    """
    clean   = clean_text(text)
    emb     = _sbert.encode([f"{_prefix}: {clean}"], normalize_embeddings=True)
    pred    = _clf.predict(emb)[0]
    proba   = _clf.predict_proba(emb)[0]

    top_idx    = np.argsort(proba)[-top_k:][::-1]
    top_results = [(_classes[i], round(float(proba[i]) * 100, 1)) for i in top_idx]

    return pred, top_results


print("✓ Fungsi predict_kategori siap digunakan")

# ── Uji prediksi ─────────────────────────────────────────────
test_cases = [
    "beli kopi janji jiwa dan roti",
    "bayar makan pakai gopay",
    "transfer ke mama lewat BCA mobile",
    "bayar gym membership bulanan",
    "beli cat akrilik untuk melukis",
    "bayar tagihan listrik PLN",
    "topup OVO untuk belanja",
    "beli beras 5kg di pasar",
]

print(f"{'Teks':<40} {'Prediksi':<25} {'Confidence':<10}")
print("-" * 80)

for teks in test_cases:
    pred, top3 = predict_kategori(teks)
    conf = top3[0][1]
    print(f"{teks[:38]:<40} {pred:<25} {conf:>6.1f}%")

print()
print("Detail top-3 untuk kasus pertama:")
pred, top3 = predict_kategori(test_cases[0])
for kat, score in top3:
    bar = '█' * int(score / 5)
    print(f"  {kat:<25} {score:>5.1f}% {bar}")
# Out:
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# ✓ Model inference siap (41 kategori)
# ✓ Fungsi predict_kategori siap digunakan
# Teks                                     Prediksi                  Confidence
# --------------------------------------------------------------------------------
# beli kopi janji jiwa dan roti            Makanan & Minuman           80.8%
# bayar makan pakai gopay                  Makanan & Minuman           51.9%
# transfer ke mama lewat BCA mobile        Transfer & Topup            54.7%
# bayar gym membership bulanan             Olahraga & Fitness          85.3%
# beli cat akrilik untuk melukis           Hobi                        95.2%
# bayar tagihan listrik PLN                Tagihan                     97.6%
# topup OVO untuk belanja                  Transfer & Topup            86.5%
# beli beras 5kg di pasar                  Belanja Harian              75.4%
#
# Detail top-3 untuk kasus pertama:
#   Makanan & Minuman          80.8% ████████████████
#   Belanja Harian              6.6% █
#   Hobi                        2.5%

# %% [markdown]
# ### 🧪 Uji Model dengan Contoh Baru

# %%
# ── Uji prediksi dengan input user ─────────────────────────────

print("Masukkan deskripsi transaksi (ketik 'exit' untuk keluar):\n")

while True:
    user_input = input("Deskripsi: ")
    if user_input.lower() == 'exit':
        break

    if user_input:
        pred, top3 = predict_kategori(user_input)
        print(f"  Prediksi Utama  : {pred}")
        print(f"  Top-K Prediksi  :")
        for kat, score in top3:
            bar = '█' * int(score / 5)
            print(f"    - {kat:<25} {score:>5.1f}% {bar}")
    else:
        print("  Deskripsi tidak boleh kosong.")
    print("\n" + "-" * 50 + "\n")
# Out:
# Masukkan deskripsi transaksi (ketik 'exit' untuk keluar):
#
# Deskripsi: Makan
#   Prediksi Utama  : Makanan & Minuman
#   Top-K Prediksi  :
#     - Makanan & Minuman          48.8% █████████
#     - Belanja Harian              6.3% █
#     - Administrasi & Dokumen      4.5%
#
# --------------------------------------------------
#
# Deskripsi: Beli goreng
#   Prediksi Utama  : Makanan & Minuman
#   Top-K Prediksi  :
#     - Makanan & Minuman          18.5% ███
#     - Belanja Harian             14.3% ██
#     - Perlengkapan Rumah          5.3% █
#
# --------------------------------------------------
#
# Deskripsi: exit

# %%
"""### 🧪 Input Deskripsi Massal"""

# Tulis deskripsi satu per baris
deskripsi_list = """
Bayar premi jiwa tahunan BCA Life
Belanja sayur dan bumbu dapur di Indomaret
Biaya transfer antar bank BRI ke Mandiri
Bayar tambal ban motor mendadak pinggir jalan
Cetak banner promosi untuk toko online
Bayar angsuran motor bulan ini
Transfer zakat penghasilan ke BAZNAS
Beli headphone Sony WH-1000XM5
Beli skin karakter di Mobile Legends
Beli bunga dan coklat ulang tahun sahabat
Beli makanan kering kucing Royal Canin
Nonton konser Coldplay di GBK
Beli cat watercolor Winsor & Newton
Bayar uang muka apartemen di Serpong
Bayar jasa desain logo brand baru
Beli sabun muka Cetaphil dan toner
Kirim uang bulanan ke adik di Bandung
Ganti oli mesin Yamaha NMAX
Beli obat batuk dan vitamin C di apotek
Bayar biaya fotokopi dan jilid dokumen
Bayar Netflix dan Spotify bulan ini
Pesan tiket pesawat Bali pp
Makan siang di warteg depan kantor
Bayar iuran gym bulan Januari
Bayar pajak penghasilan tahunan SPT
Beli kemeja flanel untuk kerja
Bayar parkir mall tiga jam
Terima gaji bulan Maret
Bayar SPP kursus bahasa Inggris
Potong rambut dan creambath di salon
Pasang keramik kamar mandi bocor
Beli rak buku kayu untuk ruang tamu
DP catering pernikahan adik
Isi paket data Telkomsel 30 hari
Bayar iuran RT dan kebersihan lingkungan
Transfer ke rekening deposito BCA
Bayar tagihan air PDAM bulan ini
Bayar kos bulanan daerah Tebet
Topup saldo GoPay untuk belanja
Naik Grab dari rumah ke stasiun
""".strip().splitlines()

print(f"Total input: {len(deskripsi_list)} deskripsi\n")
print(f"{'No':<4} {'Deskripsi':<45} {'Prediksi':<25} {'Confidence'}")
print("-" * 95)

for i, teks in enumerate(deskripsi_list, 1):
    teks = teks.strip()
    if not teks:
        continue
    pred, top3 = predict_kategori(teks)
    conf = top3[0][1]
    print(f"{i:<4} {teks[:43]:<45} {pred:<25} {conf:>6.1f}%")
# Out:
# Total input: 40 deskripsi
#
# No   Deskripsi                                     Prediksi                  Confidence
# -----------------------------------------------------------------------------------------------
# 1    Bayar premi jiwa tahunan BCA Life             Asuransi                    94.1%
# 2    Belanja sayur dan bumbu dapur di Indomaret    Belanja Harian              98.2%
# 3    Biaya transfer antar bank BRI ke Mandiri      Biaya Admin & Bank          79.5%
# 4    Bayar tambal ban motor mendadak pinggir jal   Biaya Darurat               77.4%
# 5    Cetak banner promosi untuk toko online        Pendidikan                  14.8%
# 6    Bayar angsuran motor bulan ini                Cicilan & Utang             77.1%
# 7    Transfer zakat penghasilan ke BAZNAS          Donasi/Zakat                49.7%
# 8    Beli headphone Sony WH-1000XM5                Gadget & Elektronik         82.1%
# 9    Beli skin karakter di Mobile Legends          Gaming                      75.0%
# 10   Beli bunga dan coklat ulang tahun sahabat     Hadiah                      90.1%
# 11   Beli makanan kering kucing Royal Canin        Hewan Peliharaan            97.0%
# 12   Nonton konser Coldplay di GBK                 Hiburan                     79.1%
# 13   Beli cat watercolor Winsor & Newton           Hobi                        74.1%
# 14   Bayar uang muka apartemen di Serpong          Tempat Tinggal              70.4%
# 15   Bayar jasa desain logo brand baru             Jasa Profesional            72.3%
# 16   Beli sabun muka Cetaphil dan toner            Perawatan Diri              39.6%
# 17   Kirim uang bulanan ke adik di Bandung         Keluarga                    56.2%
# 18   Ganti oli mesin Yamaha NMAX                   Perbaikan & Maintenance     54.7%
# 19   Beli obat batuk dan vitamin C di apotek       Kesehatan                   86.3%
# 20   Bayar biaya fotokopi dan jilid dokumen        Administrasi & Dokumen      43.2%
# 21   Bayar Netflix dan Spotify bulan ini           Langganan Digital           47.6%
# 22   Pesan tiket pesawat Bali pp                   Liburan                     45.4%
# 23   Makan siang di warteg depan kantor            Makanan & Minuman           85.8%
# 24   Bayar iuran gym bulan Januari                 Olahraga & Fitness          63.0%
# 25   Bayar pajak penghasilan tahunan SPT           Pajak                       96.2%
# 26   Beli kemeja flanel untuk kerja                Pakaian                     90.1%
# 27   Bayar parkir mall tiga jam                    Parkir & Tol                82.0%
# 28   Terima gaji bulan Maret                       Sosial & Komunitas          11.5%
# 29   Bayar SPP kursus bahasa Inggris               Pendidikan                  91.5%
# 30   Potong rambut dan creambath di salon          Perawatan Diri              90.0%
# 31   Pasang keramik kamar mandi bocor              Perbaikan & Maintenance     45.6%
# 32   Beli rak buku kayu untuk ruang tamu           Perlengkapan Rumah          64.4%
# 33   DP catering pernikahan adik                   Pernikahan & Event          75.2%
# 34   Isi paket data Telkomsel 30 hari              Pulsa & Data                95.4%
# 35   Bayar iuran RT dan kebersihan lingkungan      Sosial & Komunitas          54.7%
# 36   Transfer ke rekening deposito BCA             Transfer & Topup            64.3%
# 37   Bayar tagihan air PDAM bulan ini              Tagihan                     88.3%
# 38   Bayar kos bulanan daerah Tebet                Tempat Tinggal              49.4%
# 39   Topup saldo GoPay untuk belanja               Transfer & Topup            98.3%
# 40   Naik Grab dari rumah ke stasiun               Transportasi                98.8%
